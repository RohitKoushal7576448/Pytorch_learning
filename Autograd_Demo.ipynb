# %%
import torch

# %%
x=torch.tensor(3.0,requires_grad=True)#tensor ka derivati calculate karna chahate hai requires_grad True chahiye

# %%
y=x**2

# %%
x

# %%
y.backward()

# %%
x.grad

# %%
y

# %%
import math

# %%
def dz_dx(x):
  return 2*x*math.cos(x**2)

# %%
dz_dx(3)

# %%
x=torch.tensor(3.0,requires_grad=True)

# %%
y=x**2

# %%
x

# %%
y

# %%
z=torch.sin(y)

# %%
z

# %%
z.backward()

# %%
x.grad

# %%
## Manualy calculate Derivatives

# %%
x=torch.tensor(6.7)
y=torch.tensor(0.0)

# %%
w=torch.tensor(1.0)
b=torch.tensor(0.0)

# %%
#Binary cross_entropy loss for scalar
def binary_cross_entropy_loss(prediction,target):
  epsilon=1e-8
  prediction=torch.clamp(prediction,epsilon,1-epsilon)
  return(target*torch.log(prediction)+(1-target)*torch.log(1-prediction))

# %%
#fowar pass
z=w*x+b

# %%
y_pred=torch.sigmoid(z)

# %%
loss=binary_cross_entropy_loss(y_pred,y)

# %%
#Derivatives
dloss_dy_pred=(y_pred-y)/(y_pred*(1-y_pred))

dy_pred_dz=y_pred*(1-y_pred)

dz_dw=x
dz_db=1

dl_dw=dloss_dy_pred*dy_pred_dz*dz_dw
dl_db=dloss_dy_pred*dy_pred_dz*dz_db

# %%
print(f'manual gradient of loss w r t weight:{dl_dw}')
print(f'manual gradient of loss w r t bias:{dl_db}')

# %%
##Calculate Derivatives by using Pytorch

# %%
x=torch.tensor(6.7)
y=torch.tensor(0.0)

# %%
w=torch.tensor(1.0,requires_grad=True)
b=torch.tensor(0.0,requires_grad=True)

# %%
w

# %%
b

# %%
z=w*x+b

# %%
z

# %%
y_pred=torch.sigmoid(z)

# %%
y

# %%
loss=binary_cross_entropy_loss(y_pred,y)

# %%
loss

# %%
loss.backward()

# %%
print(w.grad)
print(b.grad)

# %%
#Vector input
x=torch.tensor([1,2,3],requires_grad=True,dtype=torch.float32)

# %%
x

# %%
y=(x**2).mean()

# %%
y

# %%
y.backward()

# %%
x.grad

# %%
#Clearing  grad

# %%
x=torch.tensor(2.0,requires_grad=True)

# %%
x

# %%
y=x**2

# %%
y.backward()

# %%
x.grad

# %%
x.grad.zero_()

# %%
##Its Very Important

# %%
#--requires_grad(False)
#--detach()
#torch.no_grad()

# %%
x

# %%
y=torch.tensor(5.6,requires_grad=True)

# %%
y

# %%
# Y ka required grad bandh ho gaya
y.requires_grad_(False)

# %%
y

# %%
z=y**2

# %%
z

# %%
z.backward()

# %%
#--detach()
x=torch.tensor(2.0,requires_grad=True)

# %%
x

# %%
z=x.detach()

# %%
z

# %%
y=x**2

# %%
y

# %%
y1=z**2

# %%
y1

# %%
y1.backward()

# %%
#torch.no_grad()
x=torch.tensor(2.0,requires_grad=True)

# %%
x

# %%
with torch.no_grad():
  y=x**2

# %%
y

# %%
y.backward()
